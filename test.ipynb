# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x, y = np.linspace(-10, 10, 100), np.linspace(-10, 10, 100)
X, Y = np.meshgrid(x, y)
plt.imshow(np.sin(X+Y),extent=[-20, 20, -20, 20])
plt.gca().set(xlim=(-20, 20), ylim=(-20, 20))
# Out:
# [(-20.0, 20.0), (-20.0, 20.0)]
